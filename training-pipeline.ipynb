# %% [markdown]
# # Model Training

# %%
# Model training and tuning
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# Hopsworks platform and feature store
import hopsworks
from hsfs.feature import Feature
from hsml.schema import Schema
from hsml.model_schema import ModelSchema

# General-purpose libraries
import numpy as np
import joblib
import os

# %% [markdown]
# ## Connecting to Hopsworks

# %%
project = hopsworks.login()
fs = project.get_feature_store()
# Out:
# Connected. Call `.close()` to terminate connection gracefully.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1133716
# 2024-10-27 12:17:26,951 WARNING: using legacy validation callback
# Connected. Call `.close()` to terminate connection gracefully.

# %%
earthquakes_fs = fs.get_feature_group(name="earthquakes", version=1)
query = earthquakes_fs.select_all()
feature_view = fs.get_or_create_feature_view(name="earthquakes", version=1, labels=["mag"], query=query)
# Out:
# Feature view created successfully, explore it at
# https://c.app.hopsworks.ai:443/p/1133716/fs/1124419/fv/earthquakes/version/1

# %% [markdown]
# ## Train/Test Split

# %%
X_train, X_test, y_train, y_test = feature_view.train_test_split(0.2)
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (152.30s)
# 2024-10-27 13:01:42,270 WARNING: VersionWarning: Incremented version to `1`.

# %%
X_train.drop(columns=['id', 'time'], inplace=True)
X_test.drop(columns=['id', 'time'], inplace=True)

# %%
X_train
# Out:
#          latitude   longitude    depth  deptherror   rms  reviewed
# 0        8.976400  126.256900  77.0290    6.848000  0.41       1.0
# 1       51.859500 -178.019333   3.8100    1.160000  0.18       1.0
# 2       31.614000 -103.995000   7.5482    0.385222  0.10       1.0
# 4       51.807500 -177.984500  -1.7600    1.010000  0.13       1.0
# 5       33.676167 -116.987000   9.8100    0.400000  0.07       1.0
# ...           ...         ...      ...         ...   ...       ...
# 167203  38.817167 -122.817500   2.4300    0.620000  0.02       1.0
# 167204  34.030167 -117.553667  11.8500    0.330000  0.14       1.0
# 167205  33.347667 -116.340167  13.5600    0.660000  0.20       1.0
# 167206  33.440000 -116.556000  10.0600    0.340000  0.13       1.0
# 167207  -2.116800  100.585800  65.7420    8.314000  0.56       1.0
#
# [133766 rows x 6 columns]

# %% [markdown]
# ## Model Training

# %%
model = HistGradientBoostingRegressor()

params = {'learning_rate': [0.1, 0.01, 0.001], 'l2_regularization': [0, 1e-5, 1e-3],
          'max_iter': [50, 100, 200, 300], 'max_leaf_nodes': [21, 32, 41, 51],
          'min_samples_leaf': [10, 15, 20, 30, 50]}

gs = RandomizedSearchCV(model, params, scoring='neg_mean_squared_error', n_iter=50)
gs.fit(X_train, y_train.values.ravel())
gs.cv_results_
# Out:
# {'mean_fit_time': array([46.6086762 , 55.38788981,  3.95370631,  1.03344259,  1.70561438,
#          5.06452518, 16.76599922,  9.74602556,  3.11583352,  4.67550745,
#         10.47686524, 13.14198413,  5.3938314 ,  2.14934468,  1.96487966,
#         11.48361406,  7.98168588, 16.31535268,  2.23444295,  9.13930101,
#          9.32534075, 12.95412493,  5.7318881 , 10.80747213, 10.6608027 ,
#          2.46382508,  1.66468315,  7.44494667,  3.82358537,  8.23185687,
#          3.07700071,  6.50402336,  7.02529764,  8.51303797,  2.3146594 ,
#          1.9899663 ,  7.08103676,  3.51435733,  2.24665322, 12.65068235,
#          3.091747  ,  9.22259827,  4.4507112 ,  5.22776108,  1.91727533,
#          1.74796877,  8.10907378,  7.95662889,  4.56613946,  2.09121294]),
#  'std_fit_time': array([58.20542698, 46.19474496,  0.8938125 ,  0.17063081,  0.21739717,
#          1.86060773,  2.78399978,  0.95346771,  0.44637559,  0.56047455,
#          1.23553299,  3.31509091,  0.83876083,  1.21442485,  0.39016854,
#          1.11719187,  2.05146271,  5.47057854,  0.64067756,  1.33533124,
#          0.88172342,  0.89842534,  0.82338914,  1.51483961,  2.15272044,
#          0.47109161,  0.34321152,  0.98252857,  0.37268053,  1.6796269 ,
#          0.56952944,  0.11920011,  0.90109016,  2.07693864,  0.3817104 ,
#          0.58390764,  0.67736875,  0.41052407,  0.79789683,  0.70450573,
#          0.40846543,  0.84691523,  0.49864328,  0.7478776 ,  0.42584891,
#          0.245162  ,  1.24649146,  1.01633075,  1.39260452,  0.45726594]),
#  'mean_score_time': array([2.79164863, 5.02237573, 0.55908098, 0.17963562, 0.31450796,
#         0.44941511, 1.86817117, 1.369872  , 0.36927147, 0.70039783,
#         1.4773458 , 1.95610085, 0.66188798, 0.27024088, 0.27255321,
#         2.32923808, 1.37034302, 1.94183364, 0.34608884, 1.0893322 ,
#         1.24938622, 1.96831913, 1.18772645, 1.14803934, 1.24484382,
#         0.30641837, 0.30731297, 1.14985633, 0.60679917, 1.17834964,
#         0.54999189, 1.05061927, 1.00937257, 1.18863044, 0.40342555,
#         0.25906491, 0.95155115, 0.59446273, 0.30971279, 1.59271188,
#         0.56417913, 1.27783213, 0.71075211, 1.18720427, 0.25746522,
#         0.24996948, 1.04613295, 1.55587969, 0.53008223, 0.29792371]),
#  'std_score_time': array([1.45546361, 5.23385649, 0.09277429, 0.04282432, 0.05772648,
#         0.1242223 , 0.30843706, 0.59604148, 0.0445911 , 0.04269155,
#         0.19657176, 0.2438916 , 0.11318796, 0.08271183, 0.04590552,
#         1.07575507, 0.42866099, 0.63132448, 0.1019263 , 0.30163172,
#         0.15169187, 0.3371323 , 0.11829515, 0.28051949, 0.26313523,
#         0.05652269, 0.03479151, 0.44460022, 0.10256022, 0.21849478,
#         0.11697759, 0.20152729, 0.25811547, 0.28279403, 0.0807581 ,
#         0.05943618, 0.1690267 , 0.08926703, 0.07112939, 0.28522375,
#         0.04162131, 0.23758679, 0.28004717, 0.30826817, 0.08891271,
#         0.06607115, 0.20337746, 0.20020774, 0.16155849, 0.03046369]),
#  'param_min_samples_leaf': masked_array(data=[15, 10, 20, 15, 15, 50, 30, 15, 20, 15, 15, 50, 15, 20,
#                     10, 50, 30, 15, 20, 30, 20, 10, 15, 15, 15, 50, 50, 20,
#                     15, 10, 50, 30, 50, 15, 50, 20, 15, 50, 20, 10, 30, 30,
#                     10, 30, 15, 15, 10, 20, 30, 30],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value=999999),
#  'param_max_leaf_nodes': masked_array(data=[21, 41, 21, 21, 21, 51, 51, 32, 51, 41, 51, 41, 41, 32,
#                     32, 32, 21, 41, 41, 51, 51, 51, 21, 51, 41, 51, 21, 21,
#                     32, 41, 32, 32, 41, 41, 21, 32, 32, 21, 41, 51, 21, 41,
#                     51, 21, 32, 32, 41, 21, 51, 41],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value=999999),
#  'param_max_iter': masked_array(data=[300, 300, 100, 50, 100, 50, 300, 300, 50, 100, 200,
#                     300, 100, 50, 50, 300, 200, 300, 50, 200, 200, 300,
#                     200, 200, 300, 50, 50, 300, 100, 200, 100, 200, 200,
#                     200, 100, 50, 300, 100, 50, 300, 100, 300, 100, 200,
#                     50, 50, 300, 300, 100, 50],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value=999999),
#  'param_learning_rate': masked_array(data=[0.01, 0.01, 0.001, 0.01, 0.1, 0.01, 0.01, 0.1, 0.001,
#                     0.01, 0.001, 0.01, 0.001, 0.001, 0.001, 0.01, 0.01,
#                     0.01, 0.1, 0.1, 0.001, 0.001, 0.001, 0.001, 0.1, 0.1,
#                     0.01, 0.1, 0.01, 0.01, 0.1, 0.01, 0.1, 0.001, 0.1,
#                     0.01, 0.1, 0.001, 0.01, 0.01, 0.01, 0.1, 0.01, 0.01,
#                     0.1, 0.01, 0.1, 0.01, 0.001, 0.001],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value=1e+20),
#  'param_l2_regularization': masked_array(data=[0.001, 1e-05, 0.0, 1e-05, 0.001, 1e-05, 1e-05, 0.001,
#                     1e-05, 0.0, 1e-05, 1e-05, 0.0, 1e-05, 0.0, 0.0, 0.001,
#                     0.0, 0.001, 1e-05, 0.0, 1e-05, 0.0, 0.001, 1e-05,
#                     1e-05, 1e-05, 0.0, 1e-05, 1e-05, 0.0, 1e-05, 0.001,
#                     0.001, 0.0, 0.001, 1e-05, 1e-05, 0.001, 0.0, 0.001,
#                     1e-05, 0.0, 0.0, 0.001, 0.001, 1e-05, 0.0, 0.0, 0.0],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value=1e+20),
#  'params': [{'min_samples_leaf': 15,
#    'max_leaf_nodes': 21,
#    'max_iter': 300,
#    'learning_rate': 0.01,
#    'l2_regularization': 0.001},
#   {'min_samples_leaf': 10,
#    'max_leaf_nodes': 41,
#    'max_iter': 300,
#    'learning_rate': 0.01,
#    'l2_regularization': 1e-05},
#   {'min_samples_leaf': 20,
#    'max_leaf_nodes': 21,
#    'max_iter': 100,
#    'learning_rate': 0.001,
#    'l2_regularization': 0},
#   {'min_samples_leaf': 15,
#    'max_leaf_nodes': 21,
#    'max_iter': 50,
#    'learning_rate': 0.01,
#    'l2_regularization': 1e-05},
#   {'min_samples_leaf': 15,
#    'max_leaf_nodes': 21,
#    'max_iter': 100,
#    'learning_rate': 0.1,
#    'l2_regularization': 0.001},
#   {'min_samples_leaf': 50,
#    'max_leaf_nodes': 51,
#    'max_iter': 50,
#    'learning_rate': 0.01,
#    'l2_regularization': 1e-05},
#   {'min_samples_leaf': 30,
#    'max_leaf_nodes': 51,
#    'max_iter': 300,
#    'learning_rate': 0.01,
#    'l2_regularization': 1e-05},
#   {'min_samples_leaf': 15,
#    'max_leaf_nodes': 32,
#    'max_iter': 300,
#    'learning_rate': 0.1,
#    'l2_regularization': 0.001},
#   {'min_samples_leaf': 20,
#    'max_leaf_nodes': 51,
#    'max_iter': 50,
#    'learning_rate': 0.001,
#    'l2_regularization': 1e-05},
#   {'min_samples_leaf': 15,
#    'max_leaf_nodes': 41,
#    'max_iter': 100,
#    'learning_rate': 0.01,
#    'l2_regularization': 0},
#   {'min_samples_leaf': 15,
#    'max_leaf_nodes': 51,
#    'max_iter': 200,
#    'learning_rate': 0.001,
#    'l2_regularization': 1e-05},
#   {'min_samples_leaf': 50,
#    'max_leaf_nodes': 41,
#    'max_iter': 300,
#    'learning_rate': 0.01,
#    'l2_regularization': 1e-05},
#   {'min_samples_leaf': 15,
#    'max_leaf_nodes': 41,
#    'max_iter': 100,
#    'learning_rate': 0.001,
#    'l2_regularization': 0},
#   {'min_samples_leaf': 20,
#    'max_leaf_nodes': 32,
#    'max_iter': 50,
#    'learning_rate': 0.001,
#    'l2_regularization': 1e-05},
#   {'min_samples_leaf': 10,
#    'max_leaf_nodes': 32,
#    'max_iter': 50,
#    'learning_rate': 0.001,
#    'l2_regularization': 0},
#   {'min_samples_leaf': 50,
#    'max_leaf_nodes': 32,
#    'max_iter': 300,
#    'learning_rate': 0.01,
#    'l2_regularization': 0},
#   {'min_samples_leaf': 30,
#    'max_leaf_nodes': 21,
#    'max_iter': 200,
#    'learning_rate': 0.01,
#    'l2_regularization': 0.001},
#   {'min_samples_leaf': 15,
#    'max_leaf_nodes': 41,
#    'max_iter': 300,
#    'learning_rate': 0.01,
#    'l2_regularization': 0},
#   {'min_samples_leaf': 20,
#    'max_leaf_nodes': 41,
#    'max_iter': 50,
#    'learning_rate': 0.1,
#    'l2_regularization': 0.001},
#   {'min_samples_leaf': 30,
#    'max_leaf_nodes': 51,
#    'max_iter': 200,
#    'learning_rate': 0.1,
#    'l2_regularization': 1e-05},
#   {'min_samples_leaf': 20,
#    'max_leaf_nodes': 51,
#    'max_iter': 200,
#    'learning_rate': 0.001,
#    'l2_regularization': 0},
#   {'min_samples_leaf': 10,
#    'max_leaf_nodes': 51,
#    'max_iter': 300,
#    'learning_rate': 0.001,
#    'l2_regularization': 1e-05},
#   {'min_samples_leaf': 15,
#    'max_leaf_nodes': 21,
#    'max_iter': 200,
#    'learning_rate': 0.001,
#    'l2_regularization': 0},
#   {'min_samples_leaf': 15,
#    'max_leaf_nodes': 51,
#    'max_iter': 200,
#    'learning_rate': 0.001,
#    'l2_regularization': 0.001},
#   {'min_samples_leaf': 15,
#    'max_leaf_nodes': 41,
#    'max_iter': 300,
#    'learning_rate': 0.1,
#    'l2_regularization': 1e-05},
#   {'min_samples_leaf': 50,
#    'max_leaf_nodes': 51,
#    'max_iter': 50,
#    'learning_rate': 0.1,
#    'l2_regularization': 1e-05},
#   {'min_samples_leaf': 50,
#    'max_leaf_nodes': 21,
#    'max_iter': 50,
#    'learning_rate': 0.01,
#    'l2_regularization': 1e-05},
#   {'min_samples_leaf': 20,
#    'max_leaf_nodes': 21,
#    'max_iter': 300,
#    'learning_rate': 0.1,
#    'l2_regularization': 0},
#   {'min_samples_leaf': 15,
#    'max_leaf_nodes': 32,
#    'max_iter': 100,
#    'learning_rate': 0.01,
#    'l2_regularization': 1e-05},
#   {'min_samples_leaf': 10,
#    'max_leaf_nodes': 41,
#    'max_iter': 200,
#    'learning_rate': 0.01,
#    'l2_regularization': 1e-05},
#   {'min_samples_leaf': 50,
#    'max_leaf_nodes': 32,
#    'max_iter': 100,
#    'learning_rate': 0.1,
#    'l2_regularization': 0},
#   {'min_samples_leaf': 30,
#    'max_leaf_nodes': 32,
#    'max_iter': 200,
#    'learning_rate': 0.01,
#    'l2_regularization': 1e-05},
#   {'min_samples_leaf': 50,
#    'max_leaf_nodes': 41,
#    'max_iter': 200,
#    'learning_rate': 0.1,
#    'l2_regularization': 0.001},
#   {'min_samples_leaf': 15,
#    'max_leaf_nodes': 41,
#    'max_iter': 200,
#    'learning_rate': 0.001,
#    'l2_regularization': 0.001},
#   {'min_samples_leaf': 50,
#    'max_leaf_nodes': 21,
#    'max_iter': 100,
#    'learning_rate': 0.1,
#    'l2_regularization': 0},
#   {'min_samples_leaf': 20,
#    'max_leaf_nodes': 32,
#    'max_iter': 50,
#    'learning_rate': 0.01,
#    'l2_regularization': 0.001},
#   {'min_samples_leaf': 15,
#    'max_leaf_nodes': 32,
#    'max_iter': 300,
#    'learning_rate': 0.1,
#    'l2_regularization': 1e-05},
#   {'min_samples_leaf': 50,
#    'max_leaf_nodes': 21,
#    'max_iter': 100,
#    'learning_rate': 0.001,
#    'l2_regularization': 1e-05},
#   {'min_samples_leaf': 20,
#    'max_leaf_nodes': 41,
#    'max_iter': 50,
#    'learning_rate': 0.01,
#    'l2_regularization': 0.001},
#   {'min_samples_leaf': 10,
#    'max_leaf_nodes': 51,
#    'max_iter': 300,
#    'learning_rate': 0.01,
#    'l2_regularization': 0},
#   {'min_samples_leaf': 30,
#    'max_leaf_nodes': 21,
#    'max_iter': 100,
#    'learning_rate': 0.01,
#    'l2_regularization': 0.001},
#   {'min_samples_leaf': 30,
#    'max_leaf_nodes': 41,
#    'max_iter': 300,
#    'learning_rate': 0.1,
#    'l2_regularization': 1e-05},
#   {'min_samples_leaf': 10,
#    'max_leaf_nodes': 51,
#    'max_iter': 100,
#    'learning_rate': 0.01,
#    'l2_regularization': 0},
#   {'min_samples_leaf': 30,
#    'max_leaf_nodes': 21,
#    'max_iter': 200,
#    'learning_rate': 0.01,
#    'l2_regularization': 0},
#   {'min_samples_leaf': 15,
#    'max_leaf_nodes': 32,
#    'max_iter': 50,
#    'learning_rate': 0.1,
#    'l2_regularization': 0.001},
#   {'min_samples_leaf': 15,
#    'max_leaf_nodes': 32,
#    'max_iter': 50,
#    'learning_rate': 0.01,
#    'l2_regularization': 0.001},
#   {'min_samples_leaf': 10,
#    'max_leaf_nodes': 41,
#    'max_iter': 300,
#    'learning_rate': 0.1,
#    'l2_regularization': 1e-05},
#   {'min_samples_leaf': 20,
#    'max_leaf_nodes': 21,
#    'max_iter': 300,
#    'learning_rate': 0.01,
#    'l2_regularization': 0},
#   {'min_samples_leaf': 30,
#    'max_leaf_nodes': 51,
#    'max_iter': 100,
#    'learning_rate': 0.001,
#    'l2_regularization': 0},
#   {'min_samples_leaf': 30,
#    'max_leaf_nodes': 41,
#    'max_iter': 50,
#    'learning_rate': 0.001,
#    'l2_regularization': 0}],
#  'split0_test_score': array([-0.21672713, -0.19255723, -1.80044081, -0.95682677, -0.17489262,
#         -0.92832897, -0.18765489, -0.14867948, -1.95458137, -0.48091185,
#         -1.50854093, -0.19256686, -1.79281011, -1.95691007, -1.95692239,
#         -0.20106289, -0.26662041, -0.19226064, -0.17237256, -0.14755377,
#         -1.50826669, -1.27643251, -1.5266045 , -1.50804594, -0.14553164,
#         -0.16771277, -0.957646  , -0.15363569, -0.49003358, -0.23847998,
#         -0.16421323, -0.24896265, -0.14982351, -1.51151441, -0.17463532,
#         -0.9416591 , -0.14778756, -1.80045591, -0.93364508, -0.18669046,
#         -0.51162414, -0.1463684 , -0.47452255, -0.26673122, -0.17699201,
#         -0.94189939, -0.14644235, -0.21667366, -1.79029022, -1.95532926]),
#  'split1_test_score': array([-0.21718537, -0.18930782, -1.80071482, -0.95746904, -0.17124175,
#         -0.92606205, -0.18474243, -0.1448795 , -1.95389931, -0.48103016,
#         -1.50647492, -0.19055686, -1.79166898, -1.95673859, -1.95665621,
#         -0.19942251, -0.26679099, -0.18972271, -0.16991206, -0.14435678,
#         -1.50674839, -1.27565577, -1.52661207, -1.50725591, -0.14237506,
#         -0.16332816, -0.95779422, -0.15118635, -0.48978966, -0.2370323 ,
#         -0.16133013, -0.24726379, -0.1469513 , -1.51100205, -0.17251974,
#         -0.93936834, -0.14492437, -1.80069015, -0.93218141, -0.18314661,
#         -0.51214854, -0.14206266, -0.47200375, -0.26646479, -0.17674548,
#         -0.94012208, -0.14282163, -0.21731268, -1.79024199, -1.95502409]),
#  'split2_test_score': array([-0.21384547, -0.18960035, -1.80365061, -0.95686205, -0.1702063 ,
#         -0.92685725, -0.18325039, -0.14564492, -1.95697288, -0.47948401,
#         -1.5091043 , -0.19008644, -1.79420856, -1.95951693, -1.96011013,
#         -0.19784459, -0.2631813 , -0.1897392 , -0.16829963, -0.14483437,
#         -1.50975997, -1.27764495, -1.52877788, -1.50926972, -0.14309621,
#         -0.16447334, -0.95511959, -0.15009329, -0.4881979 , -0.23639072,
#         -0.16124975, -0.24523142, -0.14704315, -1.51318401, -0.1707224 ,
#         -0.94088286, -0.14480214, -1.80284707, -0.93263216, -0.18264248,
#         -0.50974215, -0.1430216 , -0.47251748, -0.26274402, -0.17438753,
#         -0.9400371 , -0.14408859, -0.21371078, -1.7924774 , -1.95823898]),
#  'split3_test_score': array([-0.21156818, -0.18778762, -1.79932153, -0.95413377, -0.16905859,
#         -0.9238774 , -0.18147789, -0.14359121, -1.952514  , -0.47733137,
#         -1.50495953, -0.18815209, -1.78982162, -1.95448704, -1.95483967,
#         -0.1954913 , -0.26068506, -0.18721465, -0.16767762, -0.14352102,
#         -1.50522509, -1.27327986, -1.52481398, -1.50427176, -0.14245778,
#         -0.1632096 , -0.95322204, -0.15043976, -0.48540325, -0.23392205,
#         -0.15833072, -0.24302867, -0.14599131, -1.50883775, -0.16951853,
#         -0.93636512, -0.14382006, -1.79924603, -0.92997922, -0.18104889,
#         -0.50652049, -0.14212505, -0.47014379, -0.26069357, -0.17347447,
#         -0.93734775, -0.14192957, -0.21173983, -1.7884798 , -1.95363008]),
#  'split4_test_score': array([-0.21349939, -0.18851582, -1.78633106, -0.94874888, -0.17219296,
#         -0.9198223 , -0.18355067, -0.14628732, -1.93876828, -0.47541331,
#         -1.49580663, -0.18912469, -1.77782803, -1.94131654, -1.94151628,
#         -0.1973989 , -0.26196047, -0.18932236, -0.16849462, -0.1448297 ,
#         -1.49600435, -1.26654114, -1.51362301, -1.49581707, -0.14394431,
#         -0.1638729 , -0.94777441, -0.15209583, -0.48455746, -0.23338053,
#         -0.16237516, -0.24377254, -0.14762972, -1.49927184, -0.17160082,
#         -0.9326546 , -0.14575752, -1.7863941 , -0.92341919, -0.18295141,
#         -0.50490859, -0.14327187, -0.46814246, -0.26179445, -0.17491445,
#         -0.93110049, -0.14342019, -0.21366162, -1.77650303, -1.94000871]),
#  'mean_test_score': array([-0.21456511, -0.18955377, -1.79809177, -0.9548081 , -0.17151844,
#         -0.92498959, -0.18413526, -0.14581649, -1.95134717, -0.47883414,
#         -1.50497726, -0.19009739, -1.78926746, -1.95379384, -1.95400894,
#         -0.19824404, -0.26384765, -0.18965191, -0.1693513 , -0.14501913,
#         -1.5052009 , -1.27391085, -1.52408629, -1.50493208, -0.143481  ,
#         -0.16451935, -0.95431125, -0.15149018, -0.48759637, -0.23584111,
#         -0.1614998 , -0.24565181, -0.1474878 , -1.50876201, -0.17179936,
#         -0.938186  , -0.14541833, -1.79792665, -0.93037141, -0.18329597,
#         -0.50898878, -0.14336992, -0.47146601, -0.26368561, -0.17530279,
#         -0.93810136, -0.14374047, -0.21461971, -1.78759849, -1.95244622]),
#  'std_test_score': array([0.00210596, 0.00162973, 0.00605187, 0.0032417 , 0.0019844 ,
#         0.00295728, 0.0020466 , 0.00168983, 0.00645309, 0.00216897,
#         0.00481821, 0.00148592, 0.00589745, 0.00643894, 0.00647267,
#         0.00188606, 0.0024641 , 0.00160418, 0.00167831, 0.0013548 ,
#         0.00484058, 0.00395115, 0.00538036, 0.00484625, 0.00116944,
#         0.00165845, 0.00368298, 0.00127413, 0.00224308, 0.00191947,
#         0.0019112 , 0.0021977 , 0.00128068, 0.00494402, 0.00172992,
#         0.00330592, 0.00133465, 0.00588192, 0.00367672, 0.00185149,
#         0.0028368 , 0.00157356, 0.0021694 , 0.00246637, 0.00136133,
#         0.0037904 , 0.00152627, 0.00207406, 0.00569075, 0.00639697]),
#  'rank_test_score': array([21, 17, 46, 36, 12, 31, 16,  6, 47, 28, 39, 19, 44, 49, 50, 20, 26,
#         18, 11,  4, 40, 37, 42, 38,  2, 10, 35,  8, 29, 23,  9, 24,  7, 41,
#         13, 34,  5, 45, 32, 15, 30,  1, 27, 25, 14, 33,  3, 22, 43, 48])}

# %%
gs.best_score_
# Out:
# -0.14336991608171357

# %%
gs.best_estimator_
# Out:
# HistGradientBoostingRegressor(l2_regularization=1e-05, max_iter=300,
#                               max_leaf_nodes=41, min_samples_leaf=30)

# %%
gs.predict(X_train)
# Out:
# array([4.47425343, 1.20708176, 2.06020824, ..., 1.00536757, 0.65802333,
#        4.39186953])

# %%
y_train.values.ravel()
# Out:
# array([3.9 , 1.37, 2.1 , ..., 0.82, 0.93, 4.9 ])

# %%
score = -gs.score(X_test, y_test.values.ravel())

# %%
score
# Out:
# 0.14266585298314563

# %% [markdown]
# ## Model Registry

# %%
mr = project.get_model_registry()

model_dir="earthquakes_model"
if os.path.isdir(model_dir) == False:
    os.mkdir(model_dir)

joblib.dump(gs.best_estimator_, model_dir + "/earthquakes_model.pkl")

input_schema = Schema(X_train)
output_schema = Schema(y_train)
model_schema = ModelSchema(input_schema, output_schema)

earthquakes_model = mr.python.create_model(
    name="earthquakes_model",
    metrics={"mse" : score},
    model_schema=model_schema,
    description="Earthquake Magnitude Predictor"
)


earthquakes_model.save(model_dir)
# Out:
# Connected. Call `.close()` to terminate connection gracefully.
#   0%|          | 0/6 [00:02<?, ?it/s]
# Uploading: 0.000%|          | 0/1434088 elapsed<00:00 remaining<?
# Uploading: 0.000%|          | 0/637 elapsed<00:00 remaining<?
# Model created, explore it at https://c.app.hopsworks.ai:443/p/1133716/models/earthquakes_model/1
# Model(name: 'earthquakes_model', version: 1)
